# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjainsiddhant/Opencv_jnu_scss_assignments/blob/main/Assignment_1_openCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Using OpenCV in Python, write a program to do the following:
#  Read an image,
#  display it
#   save it**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2 as cv

# %%
#Read the image
path=r'/content/drive/MyDrive/photos/scss.jpg'
image=cv.imread(path,1)

# %%
#Display the image
from google.colab.patches import cv_imshow
cv_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=402x268 at 0x7F515B6A8190>

# %%
#save the image (save the same image as new image with name "jnu.jpg" and save it in same folder where "scss.jpg" present)
cv.imwrite("/content/drive/MyDrive/photos/jnu.jpg",image)
# Out:
# True
